# %% [markdown]
# * Start with maps in projections of maps with bqplot -> show world with different projections
# * Mention that only a few maps in bqplot, where can we get more info?
# * Now we'll talk about a few different methods - geopandas, cartopy & ipyleaflet
# * Interactive chloropeth plots with bqplot

# %%
# import our usual things
# %matplotlib inline
import cartopy
import pandas as pd
import matplotlib.pyplot as plt
import geopandas 
import ipyleaflet
import numpy as np
import bqplot

# %% [markdown]
# # Maps in bqplot
#
# Let's start with a few simple bqplots.

# %% [markdown]
# Let's check out a few other projections for world maps.

# %%
# scales
sc_geo = bqplot.Mercator() # not a great projection! 
# "axis"
shape_data = bqplot.topo_load('map_data/WorldMap.json')

# marks
shape_map = bqplot.Map(map_data=shape_data, scales={'projection':sc_geo})

# put it all together in afigure
fig = bqplot.Figure(marks=[shape_map], 
                   fig_margin={'top':0, 'bottom':0, 'left':0, 'right':0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %% [markdown]
# But also an issue:

# %%
# scales
sc_geo = bqplot.Gnomonic() # not a great projection! 
# "axis"
shape_data = bqplot.topo_load('map_data/WorldMap.json')

# marks
shape_map = bqplot.Map(map_data=shape_data, scales={'projection':sc_geo})

# put it all together in afigure
fig = bqplot.Figure(marks=[shape_map], 
                   fig_margin={'top':0, 'bottom':0, 'left':0, 'right':0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %% [markdown]
# Let's zoom in on where we are: the US

# %%
# scales
sc_geo = bqplot.AlbersUSA() # a projection from the globe (sphere) onto a plane (US centric)

# "axis" - in this case its a set of outlines
state_data = bqplot.topo_load('map_data/USStatesMap.json')

# marks
states_map = bqplot.Map(map_data=state_data, scales={'projection':sc_geo})

# put it all together in afigure
fig = bqplot.Figure(marks=[states_map], 
                   fig_margin={'top':0, 'bottom':0, 'left':0, 'right':0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %% [markdown]
# `bqplot` is nice because there are features we can display interactively, like info available in tooltips:

# %%
# scales
sc_geo = bqplot.AlbersUSA() # a projection from the globe (sphere) onto a plane (US centric)

# "axis" - in this case its a set of outlines
state_data = bqplot.topo_load('map_data/USStatesMap.json')

# hover tooltip
def_tt = bqplot.Tooltip(fields=['id', 'name'])

# marks
states_map = bqplot.Map(map_data=state_data, scales={'projection':sc_geo}, tooltip=def_tt)

# add in interactivity
states_map.interactions = {'click': 'select', 'hover': 'tooltip'}

# put it all together in afigure
fig = bqplot.Figure(marks=[states_map], 
                   fig_margin={'top':0, 'bottom':0, 'left':0, 'right':0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %% [markdown]
# Let's check out which maps we have available to us:

# %%
# !ls ~/opt/anaconda3/pkgs/bqplot-0.12.2-py_0/site-packages/bqplot/map_data
# Out:
# EuropeMap.json     USCountiesMap.json USStatesMap.json   WorldMap.json

# %% [markdown]
# So, there is not a ton of map data in there, how do we access other kinds of maps and map data?  Let's check out a few other things.

# %% [markdown]
# # Geopandas

# %% [markdown]
# Where can we get data?  There are a few that are "stored" in geopandas:

# %%
geopandas.datasets.available
# Out:
# ['naturalearth_cities', 'naturalearth_lowres', 'nybb']

# %% [markdown]
# Not many, but we plot the NYC boroughs very easy:

# %%
df = geopandas.read_file(geopandas.datasets.get_path('nybb'))
ax = df.plot(figsize=(10, 10), alpha=0.5, edgecolor='k')

# %% [markdown]
# We live in a pretty cool city, that actually has a lot of openly accessible datasets here:
#
# https://gis-cityofchampaign.opendata.arcgis.com/
#
# Specifically, you can find lots of data here: https://gis-cityofchampaign.opendata.arcgis.com/search?collection=Dataset
#
# We have a really nice interface that we can check out this data easily online.  Let's check out a map of the city council districts: https://gis-cityofchampaign.opendata.arcgis.com/datasets/city-council-districts
#
# There is a nice visualization at the top that actually plots for us a lot of useful things!  Let's see how we can access this dataset and make some plots ourselves, by going to `APIs` $\rightarrow$ `GeoJSON`.
#
# Let's grab: https://opendata.arcgis.com/datasets/1f75636917604299861fb408bbf79378_1.geojson
#
# This is showing the city council districts -- i.e. areas of Champaign that are seperated by representation on the city council.

# %%
gdf_councils = geopandas.read_file('https://opendata.arcgis.com/datasets/1f75636917604299861fb408bbf79378_1.geojson')

# %% [markdown]
# Like with any pandas dataframe, we can take a look at things:

# %%
gdf_councils.head()
# Out:
#    OBJECTID_1 District                  Council_me   ShapeSTArea  \
# 0         811        5             Vanna Pianfetti  1.827758e+08
# 1         812        3                  Angie Brix  2.007085e+08
# 2         813        1  Clarissa Nickerson Fourman  1.078965e+08
# 3         814        4                  Greg Stock  1.049800e+08
# 4         815        2                 Alicia Beck  5.164512e+07
#
#    ShapeSTLength                                           geometry
# 0  209845.933925  POLYGON ((-88.31441 40.11699, -88.31454 40.116...
# 1  145404.494177  POLYGON ((-88.27716 40.16364, -88.27732 40.163...
# 2   83420.727939  POLYGON ((-88.22283 40.16000, -88.22283 40.160...
# 3   77363.320814  POLYGON ((-88.26890 40.12733, -88.27076 40.127...
# 4   62243.277115  POLYGON ((-88.23537 40.10798, -88.23537 40.107...

# %% [markdown]
# In this case, `describe` probably won't help us, but we do have this available to us:

# %%
gdf_councils.describe()
# Out:
#        OBJECTID_1   ShapeSTArea  ShapeSTLength
# count    5.000000  5.000000e+00       5.000000
# mean   813.000000  1.296012e+08  115655.550794
# std      1.581139  6.131525e+07   61471.695860
# min    811.000000  5.164512e+07   62243.277115
# 25%    812.000000  1.049800e+08   77363.320814
# 50%    813.000000  1.078965e+08   83420.727939
# 75%    814.000000  1.827758e+08  145404.494177
# max    815.000000  2.007085e+08  209845.933925

# %% [markdown]
# We can also make quick plots:

# %%
gdf_councils.plot()

# %% [markdown]
# We can make fancier plots with matplotlib:

# %%
fig, ax = plt.subplots(figsize=(10,10))

gdf_councils.plot(ax=ax)

plt.show()

# %% [markdown]
# There are also a few geo-specific functions in there.  For example, we can plot out boundaries of regions:

# %%
gdf_councils.boundary.plot()

# %% [markdown]
# We can get the bounding boxes for each council district:

# %%
gdf_councils.bounds
# Out:
#         minx       miny       maxx       maxy
# 0 -88.333303  40.061894 -88.257012  40.116995
# 1 -88.315071  40.098268 -88.239120  40.163956
# 2 -88.277158  40.107938 -88.221225  40.163721
# 3 -88.276971  40.083257 -88.240119  40.127432
# 4 -88.257818  40.083182 -88.228505  40.116346

# %% [markdown]
# We can also find the centers of each of each specific shape:

# %%
gdf_councils.centroid # ignoring .to_crs() error for now
# Out:
# <ipython-input-16-1fd8ccfe6053>:1: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_councils.centroid
# 0    POINT (-88.29998 40.08731)
# 1    POINT (-88.28231 40.13389)
# 2    POINT (-88.24309 40.13570)
# 3    POINT (-88.25983 40.10719)
# 4    POINT (-88.24095 40.10021)
# dtype: geometry

# %% [markdown]
# There is also information about the coordinate reference system:

# %%
gdf_councils.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %% [markdown]
# This is a specific projection & coordinate system:
#
# https://spatialreference.org/ref/epsg/wgs-84/
#
# https://epsg.io/4326

# %% [markdown]
# We can use geopandas to overplot data as well.  Let's also overlay the properties that the city owns: https://gis-cityofchampaign.opendata.arcgis.com/datasets/city-owned-properties

# %%
gdf_props = geopandas.read_file('https://opendata.arcgis.com/datasets/3ecbc7baf1a44110a98f6d4420432000_2.geojson')

# %%
fig, ax = plt.subplots(figsize=(10,10))

gdf_councils.plot(ax=ax)

gdf_props.plot(ax=ax, color='green')

plt.show()

# %% [markdown]
# We can move to our area:

# %%
fig, ax = plt.subplots(figsize=(10,10))

gdf_councils.plot(ax=ax)

gdf_props.plot(ax=ax, color='green')

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)

plt.show()

# %% [markdown]
# ### Extra: apartments & building types too
#
# This will do a bit of data manipulation to be able to plot apartments with different color schemes.

# %%
gdf_apts = geopandas.read_file('https://opendata.arcgis.com/datasets/64154052c5a040e287bae1583d727825_8.geojson')

# %% [markdown]
# Quick look:

# %%
gdf_apts.plot()

# %% [markdown]
# What can we color by?

# %%
gdf_apts.head()
# Out:
#    OBJECTID             Address        Parcel Units Stories  UniqueID  \
# 0         1  2009 Moreland Blvd  412001126038    36       3       0.0
# 1         2  2011 Moreland Blvd  412001126038    36      3        1.0
# 2         3  2007 Moreland Blvd  412001126038    24       3       2.0
# 3         4  2003 Moreland Blvd  412001126038    36       3       3.0
# 4         5  2005 Moreland Blvd  412001126038    24       3       4.0
#
#         Building_Name                     Complex_Name Case_Number  \
# 0  2009 Moreland Blvd  University Village at Champaign   AI07-0147
# 1  2011 Moreland Blvd  University Village at Champaign   AI07-0147
# 2  2007 Moreland Blvd  University Village at Champaign   AI07-0147
# 3  2003 Moreland Blvd  University Village at Champaign   AI07-0147
# 4  2005 Moreland Blvd  University Village at Champaign   AI07-0147
#
#   Building_Type  ... Comments Safety_Comments Fire_Alarms Sprinkler  \
# 0       Complex  ...                                  Yes       Yes
# 1       Complex  ...                                  Yes       Yes
# 2       Complex  ...                                  Yes       Yes
# 3       Complex  ...                                  Yes       Yes
# 4       Complex  ...                                  Yes       Yes
#
#   Managing_Company MFRecyclingStatus   ShapeSTArea ShapeSTLength  Shape  \
# 0             None               Yes  19657.997437    929.167804   None
# 1             None               Yes  19735.512329    950.194217   None
# 2             None               Yes  13970.178833    678.398035   None
# 3             None               Yes  19739.423340    941.358477   None
# 4             None               Yes  13065.121582    636.744457   None
#
#                                             geometry
# 0  POLYGON ((-88.25315 40.14017, -88.25315 40.140...
# 1  POLYGON ((-88.25260 40.14057, -88.25256 40.140...
# 2  POLYGON ((-88.25274 40.14045, -88.25274 40.140...
# 3  POLYGON ((-88.25154 40.13978, -88.25156 40.139...
# 4  POLYGON ((-88.25351 40.13934, -88.25348 40.139...
#
# [5 rows x 22 columns]

# %% [markdown]
# How about by the number of Stories (floors)?

# %%
gdf_apts['Stories'].unique()
# Out:
# array(['3', '3 ', '2', '1', '5', ' 1', ' 3', '6', ' 6', '4 ', '4', '20',
#        ' 4', '24', '7', ' ', '8', None, '16', '13'], dtype=object)

# %% [markdown]
# Let's clean out the None's and give them a value of 0:

# %%
gdf_apts['Stories'][gdf_apts['Stories'].isnull()] = '0' # ignorning warnings
# Out:
# <ipython-input-25-c3b1bf0985fa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_apts['Stories'][gdf_apts['Stories'].isnull()] = '0' # ignorning warnings

# %%
gdf_apts['Stories'].unique()
# Out:
# array(['3', '3 ', '2', '1', '5', ' 1', ' 3', '6', ' 6', '4 ', '4', '20',
#        ' 4', '24', '7', ' ', '8', '0', '16', '13'], dtype=object)

# %% [markdown]
# It looks like we also have some "empties" - let's change those to zeros as well:

# %%
gdf_apts['Stories'][gdf_apts['Stories']==' '] = '0'
# Out:
# <ipython-input-27-8fafdda72431>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_apts['Stories'][gdf_apts['Stories']==' '] = '0'

# %%
gdf_apts['Stories'].unique()
# Out:
# array(['3', '3 ', '2', '1', '5', ' 1', ' 3', '6', ' 6', '4 ', '4', '20',
#        ' 4', '24', '7', '0', '8', '16', '13'], dtype=object)

# %% [markdown]
# We also have some repeated "4"'s but this will be fine once we turn them into integers.  Finally, let's turn these floors into numbers:

# %%
gdf_apts['Stories'] = pd.to_numeric(gdf_apts['Stories'], errors='coerce')

# %%
gdf_apts['Stories'].unique()
# Out:
# array([ 3,  2,  1,  5,  6,  4, 20, 24,  7,  0,  8, 16, 13])

# %% [markdown]
# Looks good!  We can make a quick histogram to see what floors looks like:

# %%
gdf_apts.hist(column='Stories')
plt.show()

# %% [markdown]
# Also, let's plot!

# %%
fig, ax = plt.subplots(figsize=(20,20))
gdf_councils.plot(ax=ax, color="green")
gdf_apts.plot(column='Stories', ax=ax, cmap='rainbow')

#ax.set_xlim(-88.35, -88.2)
#ax.set_ylim(40, 40.2)
plt.show()

# %% [markdown]
# Zoomed in:

# %%
fig, ax = plt.subplots(figsize=(20,20))
gdf_councils.plot(ax=ax, color="green")
gdf_apts.plot(column='Stories', ax=ax, cmap='rainbow')

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)

plt.show()

# %%
gdf_apts['Building_Type'].unique()
# Out:
# array(['Complex', 'Building', 'House', 'Over Commercial', None, 'Other'],
#       dtype=object)

# %% [markdown]
# We have a `None` -- Got to clean again:

# %%
gdf_apts['Building_Type'][gdf_apts['Building_Type'].isnull()] = 'Not specified'
# Out:
# <ipython-input-35-0d40ef411af4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gdf_apts['Building_Type'][gdf_apts['Building_Type'].isnull()] = 'Not specified'

# %%
gdf_apts['Building_Type'].unique()
# Out:
# array(['Complex', 'Building', 'House', 'Over Commercial', 'Not specified',
#        'Other'], dtype=object)

# %% [markdown]
# Let's plot with a legend!

# %%
fig, ax = plt.subplots(figsize=(20,20))
gdf_councils.plot(ax=ax, color="green")
gdf_apts.plot(column='Building_Type', ax=ax, cmap='rainbow', categorical=True, legend=True)

ax.set_xlim(-88.245, -88.225)
ax.set_ylim(40.10, 40.125)
plt.show()

# %% [markdown]
# ## Public data with geopandas
#
# Is a bit hard to find, but you can, with a good bit of looking around, find it: https://datagateway.nrcs.usda.gov/
#
# Which can lead you to places like: https://www.census.gov/geographies/mapping-files/time-series/geo/tiger-line-file.html
#
# Let's grab the state boundaries:

# %%
gdf_states = geopandas.read_file('https://www2.census.gov/geo/tiger/TIGER2019/STATE/tl_2019_us_state.zip')

# %%
gdf_states.plot()

# %% [markdown]
# Let's zoom in to the US and take a look:

# %%
fig, ax = plt.subplots(figsize=(20,10))

gdf_states.plot(ax=ax)

ax.set_xlim(-180,-60)
ax.set_ylim(15, 75)

plt.show()

# %% [markdown]
# What other information can we grab?  More digging can lead to:
#
# Which can lead you to: https://www.census.gov/cgi-bin/geo/shapefiles/index.php?year=2019&layergroup=American+Indian+Area+Geography

# %% [markdown]
# You can download the file:

# %%
gdf_na = geopandas.read_file('/Users/jillnaiman/Downloads/tl_2019_us_aiannh/tl_2019_us_aiannh.shp')

# %% [markdown]
# Or we can ping directly as we did before.

# %%
gdf_na.head()
# Out:
#   AIANNHCE  AIANNHNS  GEOID                    NAME  \
# 0     2320  02419022  2320R                 Mohegan
# 1     9100  01930930  9100R  Golden Hill Paugussett
# 2     4110  02419484  4110R          Table Mountain
# 3     1380  01666180  1380R              Greenville
# 4     1110  00806894  1110R                Flathead
#
#                                      NAMELSAD LSAD CLASSFP COMPTYP AIANNHR  \
# 0                         Mohegan Reservation   86      D8       R       F
# 1  Golden Hill Paugussett (state) Reservation   86      D4       R       S
# 2                    Table Mountain Rancheria   85      D2       R       F
# 3                        Greenville Rancheria   85      D2       R       F
# 4                        Flathead Reservation   86      D2       R       F
#
#    MTFCC FUNCSTAT       ALAND     AWATER     INTPTLAT      INTPTLON  \
# 0  G2101        A     1767260          0  +41.4900915  -072.0940543
# 1  G2101        A      399343          0  +41.5521875  -072.2680204
# 2  G2101        A      551202          0  +36.9848914  -119.6359563
# 3  G2101        A      284692          0  +40.1487839  -120.8933989
# 4  G2101        A  5013467042  316267878  +47.4967703  -114.2842791
#
#                                             geometry
# 0  MULTIPOLYGON (((-72.08912 41.48040, -72.08900 ...
# 1  MULTIPOLYGON (((-72.26917 41.55472, -72.26774 ...
# 2  POLYGON ((-119.64092 36.98425, -119.64081 36.9...
# 3  POLYGON ((-120.89737 40.15100, -120.89733 40.1...
# 4  POLYGON ((-114.85121 47.88721, -114.81989 47.8...

# %% [markdown]
# We can see where Native American land's are on the US:

# %%
fig, ax = plt.subplots(figsize=(20,10))

gdf_states.plot(ax=ax)
gdf_na.plot(ax=ax, color='red')

ax.set_xlim(-180,-60)
ax.set_ylim(15, 75)

plt.show()

# %% [markdown]
# By type:

# %%
gdf_na['NAMELSAD'].unique()
# Out:
# array(['Mohegan Reservation',
#        'Golden Hill Paugussett (state) Reservation',
#        'Table Mountain Rancheria', 'Greenville Rancheria',
#        'Flathead Reservation', 'Bishop Reservation',
#        'Fallon Paiute-Shoshone Reservation', 'Walker River Reservation',
#        'Los Coyotes Reservation', 'Manzanita Reservation',
#        'Mesa Grande Reservation', 'Pala Reservation',
#        'Isabella Reservation', 'Mattaponi (state) Reservation',
#        'Roaring Creek Rancheria', 'Pueblo of Pojoaque',
#        'Rosebud Indian Reservation', 'Woodfords Community',
#        'Spokane Reservation', 'Chitimacha Reservation',
#        'Coos, Lower Umpqua, and Siuslaw Reservation',
#        'Pascua Pueblo Yaqui Reservation', 'Berry Creek Rancheria',
#        'Enterprise Rancheria', 'Shakopee Mdewakanton Sioux Community',
#        'Santa Rosa Rancheria', "L'Anse Reservation",
#        'Paucatuck Eastern Pequot (state) Reservation',
#        'Mississippi Choctaw Reservation', 'Duck Valley Reservation',
#        'Southern Ute Reservation', 'Ute Mountain Reservation',
#        'Shoalwater Bay Indian Reservation',
#        'Pamunkey (state) Reservation', 'Lower Sioux Indian Community',
#        'Redwood Valley Rancheria', 'Sherwood Valley Rancheria',
#        'Middletown Rancheria', 'Paiute (UT) Reservation',
#        'San Pasqual Reservation', 'Santa Ysabel Reservation',
#        'Fort Berthold Reservation', 'Mooretown Rancheria',
#        'Shinnecock (state) Reservation', 'Pine Ridge Reservation',
#        'Little Traverse Bay Reservation', 'Pleasant Point Reservation',
#        'Miccosukee Reservation', 'Laytonville Rancheria',
#        'Manchester-Point Arena Rancheria', 'Iowa (KS-NE) Reservation',
#        'Sac and Fox Nation Reservation', 'Lytton Rancheria',
#        'Yavapai-Apache Nation Reservation', 'Cabazon Reservation',
#        'Ysleta del Sur Pueblo', 'Ohkay Owingeh', 'Robinson Rancheria',
#        'Zia Pueblo', 'Warm Springs Reservation', 'North Fork Rancheria',
#        'Picayune Rancheria', 'Fort Independence Reservation',
#        'Lone Pine Reservation', 'Timbi-Sha Shoshone Reservation',
#        'Isleta Pueblo', 'Big Lagoon Rancheria', 'Blue Lake Rancheria',
#        'Prairie Band of Potawatomi Nation Reservation',
#        'Crow Creek Reservation', 'Benton Paiute Reservation',
#        'Bridgeport Reservation', 'Pinoleville Rancheria',
#        'Hollywood Reservation', 'Pueblo de Cochiti', 'Nambe Pueblo',
#        'San Ildefonso Pueblo', 'Santa Clara Pueblo',
#        'Santo Domingo Pueblo', 'Inaja and Cosmit Reservation',
#        'Jamul Indian Village', 'La Jolla Reservation',
#        'Onondaga Nation Reservation', 'St. Regis Mohawk Reservation',
#        "Tohono O'odham Nation Reservation", 'Grand Traverse Reservation',
#        'Little River Reservation', 'Grand Ronde Community',
#        'Kaibab Indian Reservation', 'Augustine Reservation',
#        'Port Gamble Reservation', 'Quartz Valley Reservation',
#        'Oneida Nation Reservation', 'San Carlos Reservation',
#        'Tonto Apache Reservation', 'Sulphur Bank Rancheria',
#        'Dry Creek Rancheria', 'Stewarts Point Rancheria',
#        'Match-e-be-nash-she-wish Band of Pottawatomi Reservation',
#        'Stewart Community', 'Klamath Reservation',
#        'Hoopa Valley Reservation', 'Fort Mojave Reservation',
#        'Smith River Rancheria', 'Duckwater Reservation',
#        'Redding Rancheria', 'Chicken Ranch Rancheria',
#        'Tuolumne Rancheria', 'Fort Pierce Reservation',
#        'La Posta Indian Reservation', "Coeur d'Alene Reservation",
#        'Nez Perce Reservation', 'Big Pine Reservation',
#        'Fort Sill Apache Indian Reservation',
#        'Capitan Grande Reservation', 'Ewiiaapaayp Reservation',
#        'Laguna Pueblo', 'Navajo Nation Reservation',
#        'Summit Lake Reservation', 'Rumsey Indian Rancheria',
#        'Tampa Reservation', 'Forest County Potawatomi Community',
#        'Sokaogon Chippewa Community', 'Skull Valley Reservation',
#        'Indian Township Reservation', 'Yavapai-Prescott Reservation',
#        'Cocopah Reservation', 'Fort Yuma Indian Reservation',
#        'Fort Belknap Reservation', 'Upper Lake Rancheria',
#        'Leech Lake Reservation', 'White Earth Reservation',
#        'Cheyenne River Reservation', 'Hoh Indian Reservation',
#        'Kootenai Reservation', 'Carson Colony', 'Crow Reservation',
#        'Spirit Lake Reservation', 'Omaha Reservation',
#        'Cold Springs Rancheria', 'Santa Rosa Reservation',
#        'Menominee Reservation', 'Karuk Reservation',
#        'Rohnerville Rancheria', 'Table Bluff Reservation',
#        'Trinidad Rancheria', 'Yurok Reservation',
#        'Bois Forte Reservation', 'Fond du Lac Reservation',
#        'Stockbridge Munsee Community', 'Kalispel Reservation',
#        'Coushatta Reservation', 'Susanville Indian Rancheria',
#        'Mashantucket Pequot Reservation', 'Tama (state) Reservation',
#        'Lac Vieux Desert Reservation', 'San Manuel Reservation',
#        'Cowlitz Reservation', 'Barona Reservation', 'Santa Ana Pueblo',
#        'Lower Brule Reservation', 'Jemez Pueblo',
#        'Jicarilla Apache Nation Reservation', 'San Felipe Pueblo',
#        'Shingle Springs Rancheria', 'Alabama-Coushatta Reservation',
#        "Rocky Boy's Reservation", 'Maricopa (Ak Chin) Indian Reservation',
#        'Big Valley Rancheria', 'Tunica-Biloxi Reservation',
#        'Rincon Reservation', 'Lac Courte Oreilles Reservation',
#        'Bad River Reservation', 'Upper Sioux Community', 'Taos Pueblo',
#        'Kickapoo (TX) Reservation', 'Mille Lacs Reservation',
#        'Catawba Reservation', 'Picuris Pueblo',
#        'Coyote Valley Reservation', 'Guidiville Rancheria',
#        'Nisqually Reservation', 'Mescalero Reservation',
#        'Port Madison Reservation', 'Santee Reservation',
#        'Umatilla Reservation', 'Battle Mountain Reservation',
#        'Colusa Rancheria', 'Cortina Indian Rancheria',
#        'Fort Peck Indian Reservation', 'Fort Bidwell Reservation',
#        'Likely Rancheria', 'Lookout Rancheria', 'XL Ranch Rancheria',
#        'Prairie Island Indian Community', 'Pokagon Reservation',
#        'Havasupai Reservation', 'Hopi Reservation',
#        'Hualapai Indian Reservation', 'Brighton Reservation',
#        'Allegany Reservation', 'Winnemucca Indian Colony',
#        'Snoqualmie Reservation', 'Muckleshoot Reservation',
#        'Puyallup Reservation', 'Stillaguamish Reservation',
#        'Tulalip Reservation', 'Fort Hall Reservation',
#        'Oil Springs Reservation', 'Lac du Flambeau Reservation',
#        'Campo Indian Reservation', 'Hopland Rancheria',
#        'Las Vegas Indian Colony', 'Moapa River Indian Reservation',
#        'Bay Mills Reservation', 'Osage Reservation',
#        'Alturas Indian Rancheria', 'Cedarville Rancheria',
#        'Schaghticoke (state) Reservation', 'Auburn Rancheria',
#        'Poospatuck (state) Reservation', 'Yomba Reservation',
#        'Sault Ste. Marie Reservation', 'Burns Paiute Indian Colony',
#        'Lummi Reservation', 'Nooksack Reservation', 'Tesuque Pueblo',
#        'Narragansett Reservation', 'Immokalee Reservation',
#        'Red Lake Reservation', 'Paskenta Rancheria',
#        'Standing Rock Reservation', 'Northwestern Shoshone Reservation',
#        'Sycuan Reservation', 'Colville Reservation',
#        'Fort McDowell Yavapai Nation Reservation',
#        'Gila River Indian Reservation', 'Salt River Reservation',
#        'Coquille Reservation', 'Cahuilla Reservation',
#        'Colorado River Indian Reservation', 'Morongo Reservation',
#        'Pechanga Reservation', 'Annette Island Reserve',
#        'Turtle Mountain Reservation', 'Poarch Creek Reservation',
#        'Agua Caliente Indian Reservation', 'Yankton Reservation',
#        'Ely Reservation', 'Siletz Reservation', 'Fort Apache Reservation',
#        'Zuni Reservation', 'Uintah and Ouray Reservation',
#        'Pauma and Yuima Reservation', 'Elk Valley Rancheria',
#        'Resighini Rancheria', 'Big Cypress Reservation',
#        'Yakama Nation Reservation', 'Lovelock Indian Colony',
#        'Houlton Maliseet Reservation', 'Penobscot Reservation',
#        'Reno-Sparks Indian Colony', 'Red Cliff Reservation',
#        'Elko Colony', 'Round Valley Reservation',
#        'Fort McDermitt Indian Reservation', 'Dresslerville Colony',
#        'Tuscarora Nation Reservation', 'Soboba Reservation',
#        'Torres-Martinez Reservation', 'Grindstone Indian Rancheria',
#        'Blackfeet Indian Reservation', 'Sandia Pueblo',
#        'Kickapoo (KS) Reservation', 'Sac and Fox/Meskwaki Settlement',
#        'Chemehuevi Reservation', 'Big Sandy Rancheria',
#        'Eastern Cherokee Reservation', 'Oneida (WI) Reservation',
#        'Chehalis Reservation', 'Quinault Reservation',
#        'Squaxin Island Reservation', 'Twenty-Nine Palms Reservation',
#        'St. Croix Reservation', 'Campbell Ranch', 'Goshute Reservation',
#        'Cow Creek Reservation', 'Viejas Reservation',
#        'Flandreau Reservation', 'Hassanamisco (state) Reservation',
#        'Ontonagon Reservation', 'Sauk-Suiattle Reservation',
#        'Swinomish Reservation', 'Big Bend Rancheria',
#        'Montgomery Creek Rancheria', 'Jackson Rancheria',
#        'Northern Cheyenne Indian Reservation', 'Cattaraugus Reservation',
#        'Tonawanda Reservation', 'Tule River Reservation',
#        'Wind River Reservation', 'Winnebago Reservation',
#        'Huron Potawatomi Reservation', "Jamestown S'Klallam Reservation",
#        'Ho-Chunk Nation Reservation', 'Ramona Village',
#        'Upper Skagit Reservation', 'MOWA Choctaw (state) Reservation',
#        'Acoma Pueblo', 'Jena Band of Choctaw Reservation',
#        'Lake Traverse Reservation', 'South Fork Reservation',
#        'Wells Colony', 'Santa Ynez Reservation',
#        'Pyramid Lake Paiute Reservation', 'Yerington Colony',
#        'Skokomish Reservation', 'Lower Elwha Reservation',
#        'Makah Indian Reservation', 'Quileute Reservation',
#        'Fallon Paiute-Shoshone Colony', 'Grand Portage Reservation',
#        'Hannahville Indian Community',
#        'Mohegan Off-Reservation Trust Land',
#        'Fallon Paiute-Shoshone (Reservation) Off-Reservation Trust Land',
#        'Manzanita Off-Reservation Trust Land',
#        'Isabella Off-Reservation Trust Land',
#        'Pojoaque Off-Reservation Trust Land',
#        'Rosebud Off-Reservation Trust Land',
#        'Spokane Off-Reservation Trust Land',
#        'Coos, Lower Umpqua, and Siuslaw Off-Reservation Trust Land',
#        'Pascua Pueblo Yaqui Off-Reservation Trust Land',
#        'Berry Creek Off-Reservation Trust Land',
#        'Enterprise Off-Reservation Trust Land',
#        'Shakopee Mdewakanton Sioux Off-Reservation Trust Land',
#        "L'Anse Off-Reservation Trust Land",
#        'Mississippi Choctaw Off-Reservation Trust Land',
#        'Ute Mountain Off-Reservation Trust Land',
#        'Shoalwater Bay Off-Reservation Trust Land',
#        'Sherwood Valley Off-Reservation Trust Land',
#        'San Pasqual Off-Reservation Trust Land',
#        'Mooretown Off-Reservation Trust Land',
#        'Little Traverse Bay Off-Reservation Trust Land',
#        'Miccosukee Off-Reservation Trust Land',
#        'Iowa (KS-NE) Off-Reservation Trust Land',
#        'Sac and Fox Nation Off-Reservation Trust Land',
#        'Yavapai-Apache Nation Off-Reservation Trust Land',
#        'Ysleta del Sur Off-Reservation Trust Land',
#        'Robinson Off-Reservation Trust Land',
#        'Zia Off-Reservation Trust Land',
#        'Warm Springs Off-Reservation Trust Land',
#        'North Fork Off-Reservation Trust Land',
#        'Picayune Off-Reservation Trust Land',
#        'Timbi-Sha Shoshone Off-Reservation Trust Land',
#        'Blue Lake Off-Reservation Trust Land',
#        'Benton Paiute Off-Reservation Trust Land',
#        'Bridgeport Off-Reservation Trust Land',
#        'Coconut Creek Trust Land', 'Seminole (FL) Trust Land',
#        'Nambe Off-Reservation Trust Land',
#        'San Ildefonso Off-Reservation Trust Land',
#        'Santa Clara Off-Reservation Trust Land',
#        "Tohono O'odham Nation Off-Reservation Trust Land",
#        'Grand Traverse Off-Reservation Trust Land',
#        'Little River Off-Reservation Trust Land', 'Ponca (NE) Trust Land',
#        'Grand Ronde Off-Reservation Trust Land',
#        'Port Gamble Off-Reservation Trust Land',
#        'Quartz Valley Off-Reservation Trust Land',
#        'Tonto Apache Off-Reservation Trust Land',
#        'Dry Creek Off-Reservation Trust Land',
#        'Stewarts Point Off-Reservation Trust Land',
#        'Match-e-be-nash-she-wish Band of Pottawatomi Off-Reservation Trust Land',
#        'Fort Mojave Off-Reservation Trust Land',
#        'Smith River Off-Reservation Trust Land', 'Pit River Trust Land',
#        'Chicken Ranch Off-Reservation Trust Land',
#        'Big Pine Off-Reservation Trust Land',
#        'Laguna Off-Reservation Trust Land',
#        'Navajo Nation Off-Reservation Trust Land',
#        'Summit Lake Off-Reservation Trust Land',
#        'Forest County Potawatomi Off-Reservation Trust Land',
#        'Sokaogon Chippewa Off-Reservation Trust Land',
#        'Fort Belknap Off-Reservation Trust Land',
#        'Leech Lake Off-Reservation Trust Land',
#        'White Earth Off-Reservation Trust Land',
#        'Wampanoag-Aquinnah Trust Land',
#        'Cheyenne River Off-Reservation Trust Land',
#        'Hoh Off-Reservation Trust Land',
#        'Kootenai Off-Reservation Trust Land', 'Celilo Village',
#        'Crow Off-Reservation Trust Land',
#        'Menominee Off-Reservation Trust Land',
#        'Karuk Off-Reservation Trust Land',
#        'Trinidad Off-Reservation Trust Land',
#        'Bois Forte Off-Reservation Trust Land',
#        'Fond du Lac Off-Reservation Trust Land',
#        'Stockbridge Munsee Off-Reservation Trust Land',
#        'Kalispel Off-Reservation Trust Land',
#        'Coushatta Off-Reservation Trust Land',
#        'Susanville Off-Reservation Trust Land',
#        'Mashantucket Pequot Off-Reservation Trust Land',
#        'San Manuel Off-Reservation Trust Land',
#        'Barona Off-Reservation Trust Land',
#        'Lower Brule Off-Reservation Trust Land',
#        'Jicarilla Apache Nation Off-Reservation Trust Land',
#        'Shingle Springs Off-Reservation Trust Land',
#        'Alabama-Coushatta Off-Reservation Trust Land',
#        "Rocky Boy's Off-Reservation Trust Land",
#        'Maricopa (Ak Chin) Off-Reservation Trust Land',
#        'Tunica-Biloxi Off-Reservation Trust Land',
#        'Rincon Off-Reservation Trust Land',
#        'Lac Courte Oreilles Off-Reservation Trust Land',
#        'Upper Sioux Off-Reservation Trust Land',
#        'Taos Off-Reservation Trust Land',
#        'Kickapoo (TX) Off-Reservation Trust Land',
#        'Mille Lacs Off-Reservation Trust Land',
#        'Guidiville Off-Reservation Trust Land',
#        'Minnesota Chippewa Trust Land',
#        'Umatilla Off-Reservation Trust Land',
#        'Battle Mountain Off-Reservation Trust Land',
#        'Fort Peck Off-Reservation Trust Land',
#        'Fort Bidwell Off-Reservation Trust Land',
#        'Prairie Island Off-Reservation Trust Land',
#        'Pokagon Off-Reservation Trust Land',
#        'Hopi Off-Reservation Trust Land',
#        'Hualapai Off-Reservation Trust Land',
#        'Muckleshoot Off-Reservation Trust Land',
#        'Puyallup Off-Reservation Trust Land',
#        'Stillaguamish Off-Reservation Trust Land',
#        'Tulalip Off-Reservation Trust Land',
#        'Fort Hall Off-Reservation Trust Land',
#        'Bay Mills Off-Reservation Trust Land',
#        'Cedarville Off-Reservation Trust Land',
#        'Auburn Off-Reservation Trust Land',
#        'Sault Ste. Marie Off-Reservation Trust Land',
#        'Burns Paiute Off-Reservation Trust Land',
#        'Nooksack Off-Reservation Trust Land',
#        'Tesuque Off-Reservation Trust Land',
#        'Sycuan Off-Reservation Trust Land',
#        'Colville Off-Reservation Trust Land',
#        'Morongo Off-Reservation Trust Land',
#        'Turtle Mountain Off-Reservation Trust Land',
#        'Poarch Creek Off-Reservation Trust Land',
#        'Agua Caliente Off-Reservation Trust Land',
#        'Siletz Off-Reservation Trust Land',
#        'Zuni Off-Reservation Trust Land',
#        'Uintah and Ouray Off-Reservation Trust Land',
#        'Washoe Ranches Trust Land',
#        'Elk Valley Off-Reservation Trust Land',
#        'Passamaquoddy Trust Land',
#        'Yakama Nation Off-Reservation Trust Land',
#        'Houlton Maliseet Off-Reservation Trust Land',
#        'Penobscot Off-Reservation Trust Land',
#        'Reno-Sparks Off-Reservation Trust Land',
#        'Red Cliff Off-Reservation Trust Land',
#        'Round Valley Off-Reservation Trust Land',
#        'Soboba Off-Reservation Trust Land',
#        'Blackfeet Off-Reservation Trust Land',
#        'Sac and Fox/Meskwaki Off-Reservation Trust Land',
#        'Big Sandy Off-Reservation Trust Land',
#        'Oneida (WI) Off-Reservation Trust Land',
#        'Chehalis Off-Reservation Trust Land',
#        'Squaxin Island Off-Reservation Trust Land',
#        'Twenty-Nine Palms Off-Reservation Trust Land',
#        'St. Croix Off-Reservation Trust Land',
#        'Cow Creek Off-Reservation Trust Land',
#        'Aroostook Band of Micmac Trust Land',
#        'Viejas Off-Reservation Trust Land',
#        'Swinomish Off-Reservation Trust Land',
#        'Northern Cheyenne Off-Reservation Trust Land',
#        'Tule River Off-Reservation Trust Land',
#        'Wind River Off-Reservation Trust Land',
#        'Winnebago Off-Reservation Trust Land',
#        'Huron Potawatomi Off-Reservation Trust Land',
#        "Jamestown S'Klallam Off-Reservation Trust Land",
#        'Ho-Chunk Nation Off-Reservation Trust Land',
#        'Upper Skagit Off-Reservation Trust Land',
#        'Acoma Off-Reservation Trust Land',
#        'Lake Traverse Off-Reservation Trust Land',
#        'South Fork Off-Reservation Trust Land',
#        'Skokomish Off-Reservation Trust Land',
#        'Lower Elwha Off-Reservation Trust Land',
#        'Fallon Paiute-Shoshone (Colony) Off-Reservation Trust Land',
#        'Grand Portage Off-Reservation Trust Land',
#        'Hannahville Off-Reservation Trust Land',
#        'Mashpee Wampanoag Trust Land',
#        'Princess Kahanu Estates Hawaiian Home Land',
#        'Kakaina-Kumuhau Hawaiian Home Land',
#        'Kalaeloa Hawaiian Home Land', 'Kalawahine Hawaiian Home Land',
#        'Kawaihae Hawaiian Home Land', 'Kealakehe Hawaiian Home Land',
#        'Keaukaha Hawaiian Home Land', 'Keoniki Hawaiian Home Land',
#        'East Kapolei Hawaiian Home Land', 'Haiku Hawaiian Home Land',
#        'Honokowai Hawaiian Home Land', 'Paukukalo Hawaiian Home Land',
#        'Pulehunui Hawaiian Home Land', 'South Maui Hawaiian Home Land',
#        'Waiehu Hawaiian Home Land', 'Leialii Hawaiian Home Land',
#        'Makaha Valley Hawaiian Home Land', 'Maluohai Hawaiian Home Land',
#        'Maili Hawaiian Home Land', 'Pearl City Hawaiian Home Land',
#        'Piihonua Hawaiian Home Land', 'Ponohawaii Hawaiian Home Land',
#        'Kanehili Hawaiian Home Land',
#        'Anahola (Residential) Hawaiian Home Land',
#        'Hanapepe Hawaiian Home Land', 'Kapaa Hawaiian Home Land',
#        'Kekaha Hawaiian Home Land', 'Kaupea Hawaiian Home Land',
#        'Keahuolu Hawaiian Home Land', 'Waiahole Hawaiian Home Land',
#        'Waiku-Hana Hawaiian Home Land', 'Waianae Kai Hawaiian Home Land',
#        'Upolu Hawaiian Home Land',
#        'Panaewa (Agricultural) Hawaiian Home Land',
#        'Pauahi Hawaiian Home Land',
#        'Panaewa (Residential) Hawaiian Home Land',
#        'Puukapu Hawaiian Home Land', 'Waiohinu Hawaiian Home Land',
#        'Kalaupapa Hawaiian Home Land', 'Lalamilo Hawaiian Home Land',
#        'Keokea (Agricultural) Hawaiian Home Land',
#        'Makuu Hawaiian Home Land', 'Nienie Hawaiian Home Land',
#        'Kaohe-Olaa Hawaiian Home Land', 'Waiakea Hawaiian Home Land',
#        'Wailau Hawaiian Home Land', 'Waimanu Hawaiian Home Land',
#        'Hoolehua-Palaau Hawaiian Home Land',
#        'Kahikinui Hawaiian Home Land', 'Kalamaula Hawaiian Home Land',
#        'Kamiloloa-Makakupaia Hawaiian Home Land',
#        'Honokaia Hawaiian Home Land', 'Honomu Hawaiian Home Land',
#        'Homuula-Upper Piihonua Hawaiian Home Land',
#        'Kolaoa Hawaiian Home Land', 'Kamaoa-Puueo Hawaiian Home Land',
#        'Kamoku-Kapulena Hawaiian Home Land', 'Kaumana Hawaiian Home Land',
#        'Kapaakea Hawaiian Home Land', 'Keanae-Wailua Hawaiian Home Land',
#        'Waiohuli (Residential) Hawaiian Home Land',
#        'Moloaa Hawaiian Home Land', 'Wailua Hawaiian Home Land',
#        'Waimea Hawaiian Home Land', 'Kewalo Hawaiian Home Land',
#        'Ualapue Hawaiian Home Land', 'Lanai City Hawaiian Home Land',
#        'Lualualei Hawaiian Home Land', 'Nanakuli Hawaiian Home Land',
#        'Honolulu Makai Hawaiian Home Land', 'Waianae Hawaiian Home Land',
#        'Waimanalo Hawaiian Home Land',
#        'Anahola (Agricultural) Hawaiian Home Land',
#        'Papakolea Hawaiian Home Land', 'Kapolei Hawaiian Home Land',
#        'King Salmon ANVSA', 'Petersburg ANVSA', 'Atka ANVSA',
#        'Nikolski ANVSA', 'St. George ANVSA', 'Wrangell ANVSA',
#        'Akutan ANVSA', 'Alatna ANVSA', 'Allakaket ANVSA', 'Angoon ANVSA',
#        'Chilkat ANVSA', 'Nome ANVSA', 'Akhiok ANVSA', 'Karluk ANVSA',
#        'Larsen Bay ANVSA', 'Hughes ANVSA', 'Koyuk ANVSA',
#        "Mary's Igloo ANVSA", 'St. Michael ANVSA', 'Savoonga ANVSA',
#        'Belkofski ANVSA', 'False Pass ANVSA', 'King Cove ANVSA',
#        'Nelson Lagoon ANVSA', 'Sand Point ANVSA', 'Lesnoi ANVSA',
#        'Skagway ANVSA', 'Ketchikan ANVSA', 'Hoonah ANVSA',
#        'Tatitlek ANVSA', 'Old Harbor ANVSA', 'Ouzinkie ANVSA',
#        'Port Lions ANVSA', 'Huslia ANVSA', 'Kaltag ANVSA',
#        'Chickaloon ANVSA', 'Knik ANVSA', 'Marshall ANVSA',
#        'Mountain Village ANVSA', 'White Mountain ANVSA', 'Tazlina ANVSA',
#        'Kodiak ANVSA', 'Egegik ANVSA', 'Igiugig ANVSA', 'Iliamna ANVSA',
#        'Ivanof Bay ANVSA', 'Kokhanok ANVSA', 'Levelock ANVSA',
#        'Newhalen ANVSA', 'Nondalton ANVSA', 'Pedro Bay ANVSA',
#        'Perryville ANVSA', 'Pilot Point ANVSA', 'Port Heiden ANVSA',
#        'Ugashik ANVSA', 'Tuntutuliak ANVSA', 'Tununak ANVSA',
#        'Kasigluk ANVSA', 'Kipnuk ANVSA', 'Kongiganak ANVSA',
#        'Tuluksak ANVSA', 'Alakanuk ANVSA', 'Algaaciq ANVSA',
#        'Andreafsky ANVSA', "Bill Moore's ANVSA", 'Chevak ANVSA',
#        'Akiak ANVSA', 'Hydaburg ANVSA', 'Kasaan ANVSA', 'Klawock ANVSA',
#        'Naknek ANVSA', 'South Naknek ANVSA', 'Douglas ANVSA',
#        'Russian Mission ANVSA', 'Scammon Bay ANVSA', 'Ekwok ANVSA',
#        'Manokotak ANVSA', 'New Koliganek ANVSA', 'New Stuyahok ANVSA',
#        'Portage Creek ANVSA', 'Togiak ANVSA', 'Twin Hills ANVSA',
#        'Crooked Creek ANVSA', 'Eek ANVSA', 'Georgetown ANVSA',
#        'Goodnews Bay ANVSA', 'Kalskag ANVSA', 'Eklutna ANVSA',
#        'Dot Lake ANVSA', 'Eagle ANVSA', 'Healy Lake ANVSA',
#        'Northway ANVSA', 'Tanacross ANVSA', 'Nunam Iqua ANVSA',
#        'Ohogamiut ANVSA', 'Paimiut ANVSA', 'Pilot Station ANVSA',
#        'Pitkas Point ANVSA', 'Chuathbaluk ANVSA', 'Port Alsworth ANVSA',
#        'Chenega ANVSA', 'Chistochina ANVSA', 'Chitina ANVSA',
#        'Copper Center ANVSA', 'Canyon Village ANVSA', 'Venetie ANVSA',
#        'Wales ANVSA', 'Grayling ANVSA', 'Holy Cross ANVSA',
#        'Chignik ANVSA', 'Chignik Lagoon ANVSA', 'Chignik Lake ANVSA',
#        'Tetlin ANVSA', 'Ekuk ANVSA', 'Atqasuk ANVSA', 'Barrow ANVSA',
#        'Kaktovik ANVSA', 'Nuiqsut ANVSA', 'Point Hope ANVSA',
#        'Point Lay ANVSA', 'Lake Minchumina ANVSA', 'Chilkoot ANVSA',
#        'Aniak ANVSA', 'Atmautluak ANVSA', 'Bethel ANVSA',
#        'Cantwell ANVSA', 'Kenaitze ANVSA', 'Nanwalek ANVSA',
#        'Ninilchik ANVSA', 'Port Graham ANVSA', 'Salamatof ANVSA',
#        'Seldovia ANVSA', 'Tyonek ANVSA', 'Chuloonawick ANVSA',
#        'Emmonak ANVSA', 'Hamilton ANVSA', 'Hooper Bay ANVSA',
#        'Kotlik ANVSA', 'Wainwright ANVSA', 'Yakutat ANVSA', 'Elim ANVSA',
#        'Ambler ANVSA', 'Buckland ANVSA', 'St. Paul ANVSA',
#        'Unalaska ANVSA', 'Kwethluk ANVSA', 'Kwigillingok ANVSA',
#        'Kwinhagak ANVSA', 'Lime Village ANVSA', 'Lower Kalskag ANVSA',
#        'Mekoryuk ANVSA', 'Napaimute ANVSA', 'Saxman ANVSA',
#        'Aleknagik ANVSA', 'Clarks Point ANVSA', 'Dillingham ANVSA',
#        'Tanana ANVSA', 'Telida ANVSA', 'Kobuk ANVSA', 'Kotzebue ANVSA',
#        'Noatak ANVSA', 'Noorvik ANVSA', 'Selawik ANVSA', 'Eyak ANVSA',
#        'Gakona ANVSA', 'Gulkana ANVSA', 'Mentasta Lake ANVSA',
#        'Kake ANVSA', 'Chefornak ANVSA', 'Nulato ANVSA', 'Rampart ANVSA',
#        'Ruby ANVSA', 'Shageluk ANVSA', 'Stevens Village ANVSA',
#        'Takotna ANVSA', 'Minto ANVSA', 'Nenana ANVSA', 'Nikolai ANVSA',
#        'Anaktuvuk Pass ANVSA', 'Koyukuk ANVSA', 'Deering ANVSA',
#        'Kiana ANVSA', 'Kivalina ANVSA', 'Golovin ANVSA', 'Napakiak ANVSA',
#        'Napaskiak ANVSA', 'Shaktoolik ANVSA', 'Shishmaref ANVSA',
#        'Solomon ANVSA', 'Stebbins ANVSA', 'Teller ANVSA',
#        'Unalakleet ANVSA', 'Inalik ANVSA', 'Anvik ANVSA',
#        'Arctic Village ANVSA', 'Beaver ANVSA', 'Birch Creek ANVSA',
#        'Chalkyitsik ANVSA', 'Circle ANVSA', 'Evansville ANVSA',
#        'Fort Yukon ANVSA', 'Galena ANVSA', 'Shungnak ANVSA',
#        'McGrath ANVSA', 'Manley Hot Springs ANVSA', 'Akiachak ANVSA',
#        'Nightmute ANVSA', 'Nunapitchuk ANVSA', 'Newtok ANVSA',
#        'Craig ANVSA', 'Oscarville ANVSA', 'Platinum ANVSA',
#        'Red Devil ANVSA', 'Sleetmute ANVSA', 'Stony River ANVSA',
#        'Toksook Bay ANVSA', 'Brevig Mission ANVSA', 'Council ANVSA',
#        'Gambell ANVSA', 'Sitka ANVSA', 'Seminole OTSA', 'Chickasaw OTSA',
#        'Choctaw OTSA', 'Pawnee OTSA', 'Cherokee OTSA', 'Kaw OTSA',
#        'Ponca OTSA', 'Tonkawa OTSA', 'Otoe-Missouria OTSA', 'Creek OTSA',
#        'Kiowa-Comanche-Apache-Fort Sill Apache OTSA',
#        'Citizen Potawatomi Nation-Absentee Shawnee OTSA', 'Modoc OTSA',
#        'Ottawa OTSA', 'Peoria OTSA', 'Quapaw OTSA', 'Wyandotte OTSA',
#        'Seneca-Cayuga OTSA', 'Caddo-Wichita-Delaware OTSA',
#        'Cheyenne-Arapaho OTSA', 'Eastern Shawnee OTSA', 'Miami OTSA',
#        'Iowa OTSA', 'Sac and Fox OTSA', 'Kickapoo OTSA',
#        'Nanticoke Lenni Lenape SDTSA', 'Haliwa-Saponi SDTSA',
#        'Star Muskogee Creek SDTSA', 'Coharie SDTSA', 'Lumbee SDTSA',
#        'Waccamaw Siouan SDTSA', 'Ramapough SDTSA',
#        'Lenape Indian Tribe of Delaware SDTSA', 'Cher-O-Creek SDTSA',
#        'Cherokee Tribe of Northeast Alabama SDTSA', 'Adais Caddo SDTSA',
#        'Eastern Chickahominy SDTSA', 'Chickahominy SDTSA',
#        'United Houma Nation SDTSA', 'Upper South Carolina Pee Dee SDTSA',
#        'Clifton Choctaw SDTSA', 'Beaver Creek SDTSA', 'Waccamaw SDTSA',
#        'Pee Dee SDTSA', 'Nanticoke Indian Tribe SDTSA',
#        'Apache Choctaw SDTSA', 'Sappony SDTSA', 'Echota Cherokee SDTSA',
#        'MaChis Lower Creek SDTSA', 'Meherrin SDTSA',
#        'Occaneechi-Saponi SDTSA',
#        'United Cherokee Ani-Yun-Wiya Nation SDTSA',
#        'Four Winds Cherokee SDTSA', 'Wassamasaw SDTSA', 'Santee SDTSA',
#        'Mechoopda TDSA', 'Cayuga Nation TDSA', 'Ione Band of Miwok TDSA',
#        'Samish TDSA', 'Creek/Seminole joint-use OTSA',
#        'Kaw/Ponca joint-use OTSA', 'Miami/Peoria joint-use OTSA',
#        'Kiowa-Comanche-Apache-Ft Sill Apache/Caddo-Wichita-Delaware joint-use OTSA',
#        'Kickapoo (KS) Reservation/Sac and Fox Nation Trust Land joint-use area',
#        'San Felipe Pueblo/Santa Ana Pueblo joint-use area',
#        'San Felipe Pueblo/Santo Domingo Pueblo joint-use area'],
#       dtype=object)

# %%
fig, ax = plt.subplots(figsize=(20,10))

gdf_states.plot(ax=ax)
gdf_na.plot(column='NAMELSAD', ax=ax)

ax.set_xlim(-180,-60)
ax.set_ylim(15, 75)

plt.show()

# %% [markdown]
# ### Plot waterways
#
# One more!

# %%
gdf_water = geopandas.read_file('https://www2.census.gov/geo/tiger/TIGER2019/AREAWATER/tl_2019_01001_areawater.zip')

# %%
gdf_water.head()
# Out:
#   ANSICODE       HYDROID FULLNAME  MTFCC  ALAND   AWATER     INTPTLAT  \
# 0     None  110585123145     None  H2030      0  6799347  +32.4053710
# 1     None  110585123223     None  H2030      0    59480  +32.4038478
# 2     None  110585123208     None  H2030      0    42919  +32.3474700
# 3     None  110585123141     None  H2030      0    30450  +32.3828171
# 4     None  110585123178     None  H2030      0    60701  +32.4713894
#
#       INTPTLON                                           geometry
# 0  -86.7882530  POLYGON ((-86.78825 32.40537, -86.78823 32.405...
# 1  -86.6020994  POLYGON ((-86.60363 32.40047, -86.60359 32.400...
# 2  -86.7947210  POLYGON ((-86.79583 32.34779, -86.79579 32.347...
# 3  -86.5865927  POLYGON ((-86.58775 32.38230, -86.58771 32.382...
# 4  -86.7651146  POLYGON ((-86.76657 32.46948, -86.76650 32.469...

# %%
fig, ax = plt.subplots(figsize=(10,10))
gdf_water.plot(ax=ax)
plt.show()
# we can see this is showing data for a small subset of the US

# %% [markdown]
# Where are these waterways?

# %%
fig, ax = plt.subplots(figsize=(20,20))
gdf_states.plot(ax=ax, color='lightgray')
gdf_water.plot(ax=ax, color='magenta')

ax.set_xlim(-87, -86)
ax.set_ylim(32,33)

plt.show()

# %% [markdown]
# Let's zoom out a good deal:

# %%
fig, ax = plt.subplots(figsize=(20,20))
gdf_states.plot(ax=ax, color='lightgray')
gdf_water.plot(ax=ax, color='magenta')

ax.set_xlim(-88, -80)
ax.set_ylim(26, 34)

plt.show()

# %% [markdown]
# # Using GeoJSON data in bqplot
#
# We can use `requests` to ping websites for GeoJSON files directly.

# %%
import requests

# %%
shape_file_url = 'https://opendata.arcgis.com/datasets/1f75636917604299861fb408bbf79378_1.geojson'
gdata = requests.get(shape_file_url).json()

# %%
gdata
# Out:
# {'type': 'FeatureCollection',
#  'name': 'City_Council_Districts',
#  'crs': {'type': 'name',
#   'properties': {'name': 'urn:ogc:def:crs:OGC:1.3:CRS84'}},
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECT
#       [-88.23851130486291, 40.087138999749186],
#       [-88.23851213855727, 40.08713899953098],
#       [-88.2392448234083, 40.08713879809303],
#       [-88.23938981235692, 40.08713875815547],
#       [-88.23979043005936, 40.08713864554683],
#       [-88.23979007475282, 40.08672575197795],
#       [-88.23979007229116, 40.08672326714097],
#       [-88.23978992477498, 40.08655177017406],
#       [-88.23978966151913, 40.08624466991597],
#       [-88.23981321933103, 40.086244591668915],
#       [-88.23982596383586, 40.086244549720504],
#       [-88.24001014298497, 40.08624393721223],
#       [-88.24010275024065, 40.08624362991397],
#       [-88.24011549474642, 40.08624358703309],
#       [-88.24011545943617, 40.08625400097696]]]}}]}

# %% [markdown]
# Let's use our champaign county map in bqplot maps.  First, let's zoom into IL:

# %%
sc_geo = bqplot.Mercator(scale_factor = 10000, center=(-88.2434, 40.15)) # long/lat, scale factor is default of 190

state_data = bqplot.topo_load('map_data/USStatesMap.json')

def_tt = bqplot.Tooltip(fields=['id', 'name'])

states_map = bqplot.Map(map_data=state_data, scales={'projection':sc_geo}, tooltip=def_tt)
states_map.interactions = {'click': 'select', 'hover': 'tooltip'}

fig=bqplot.Figure(marks=[states_map], title='US States Map Example',
                  fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %% [markdown]
# We can use this scale to plot the Champaign county map:

# %%
sc_geo = bqplot.Mercator(scale_factor = 10000, center=(-88.2434, 40.15)) # long/lat, scale factor is default of 190

mymap = bqplot.Map(map_data=gdata, scales={'projection':sc_geo})

fig=bqplot.Figure(marks=[mymap], title='Map Example',
                  fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %% [markdown]
# That's still pretty far out, let's zoom in!

# %%
sc_geo = bqplot.Mercator(scale_factor = 200000, center=(-88.2434, 40.15)) # long/lat, scale factor is default of 190

mymap = bqplot.Map(map_data=gdata, scales={'projection':sc_geo})

fig=bqplot.Figure(marks=[mymap], title='Map Example',
                  fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(hovered_styles={'hovered_fill': '…

# %%
sc_geo = bqplot.Mercator(scale_factor = 200000, center=(-88.2434, 40.15)) # long/lat, scale factor is default of 190

def_tt = bqplot.Tooltip(fields=['District', 'Council_me'])

mymap = bqplot.Map(map_data=gdata, scales={'projection':sc_geo}, tooltip=def_tt)

mymap.colors = {'default_color':"blue"}

mymap.interactions = {'click': 'select', 'hover': 'tooltip'}

fig=bqplot.Figure(marks=[mymap], title='Map Example',
                  fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0})
fig
# Out:
# Figure(fig_margin={'top': 0, 'bottom': 0, 'left': 0, 'right': 0}, marks=[Map(colors={'default_color': 'blue'},…

# %% [markdown]
# ### ASIDE
#
# How do I find out what is supported in my tooltip?

# %%
state_data.keys()
# Out:
# dict_keys(['type', 'objects', 'transform', 'arcs'])

# %%
state_data['objects'].keys()
# Out:
# dict_keys(['land', 'subunits'])

# %%
state_data['objects']['land']
# Out:
# {'type': 'MultiPolygon',
#  'properties': {'counties': None},
#  'arcs': [[[5830,
#     6026,
#     6034,
#     6073,
#     6164,
#     6179,
#     6023,
#     6043,
#     6231,
#     6416,
#     6410,
#     6564,
#     6243,
#     6565,
#     6546,
#     6475,
#     6542,
#     6784,
#     6741,
#     6811,
#     6739,
#     6870,
#     6965,
#     7087,
#     7246,
#     -7086,
#     7247,
#     7255,
#     7256,
#     7257,
#     7305,
#     7566,
#     9399,
#     7668,
#     9397,
#     -7836,
#     9398,
#     7838,
#     8050,
#     8017,
#     8018,
#     8019,
#     8020,
#     8021,
#     8047,
#     8023,
#     8252,
#     8247,
#     8302,
#     8493,
#     8575,
#     -8491,
#     8576,
#     8671,
#     8807,
#     8877,
#     8984,
#     9074,
#     9116,
#     9138,
#     9129,
#     9073,
#     8960,
#     8874,
#     8961,
#     8956,
#     8957,
#     9090,
#     9130,
#     9181,
#     -9123,
#     9182,
#     9125,
#     9177,
#     9255,
#     9278,
#     9279,
#     9280,
#     9311,
#     9306,
#     9307,
#     9308,
#     9309,
#     9318,
#     9340,
#     9347,
#     9342,
#     9343,
#     9344,
#     9345,
#     9349,
#     9338,
#     9326,
#     9317,
#     9284,
#     9315,
#     9286,
#     9266,
#     9241,
#     9239,
#     9214,
#     9200,
#     9170,
#     9113,
#     9114,
#     9350,
#     8936,
#     8837,
#     8937,
#     9039,
#     8977,
#     9038,
#     8979,
#     8884,
#     8980,
#     8886,
#     8777,
#     -8768,
#     8778,
#     8770,
#     8761,
#     8755,
#     8642,
#     8643,
#     8644,
#     8667,
#     8810,
#     8833,
#     8851,
#     8819,
#     8981,
#     9002,
#     8999,
#     9000,
#     9064,
#     8974,
#     9059,
#     -8971,
#     9053,
#     9054,
#     9055,
#     9056,
#     9057,
#     9083,
#     9044,
#     9023,
#     9011,
#     9034,
#     8988,
#     9065,
#     9108,
#     9067,
#     8991,
#     9107,
#     9109,
#     9152,
#     9193,
#     9141,
#     9196,
#     9143,
#     9144,
#     9145,
#     9156,
#     9195,
#     9206,
#     9226,
#     9190,
#     9227,
#     9208,
#     9222,
#     9232,
#     9225,
#     9233,
#     9234,
#     9235,
#     9252,
#     9273,
#     9303,
#     9334,
#     9339,
#     9331,
#     9328,
#     9292,
#     9231,
#     9167,
#     9104,
#     8944,
#     8844,
#     8841,
#     8854,
#     8358,
#     8360,
#     7864,
#     8080,
#     8008,
#     8177,
#     8470,
#     8160,
#     7700,
#     7715,
#     7672,
#     7495,
#     7030,
#     6995,
#     6876,
#     6510,
#     5861,
#     5585,
#     5267,
#     5171,
#     5264,
#     5415,
#     5133,
#     4992,
#     4822,
#     4518,
#     4663,
#     4437,
#     4662,
#     4439,
#     4447,
#     4816,
#     4449,
#     3587,
#     2648,
#     2337,
#     1859,
#     1579,
#     1433,
#     1268,
#     954,
#     753,
#     600,
#     639,
#     586,
#     588,
#     454,
#     330,
#     221,
#     175,
#     222,
#     306,
#     264,
#     358,
#     261,
#     359,
#     308,
#     394,
#     357,
#     294,
#     184,
#     172,
#     185,
#     126,
#     2,
#     73,
#     83,
#     78,
#     81,
#     22,
#     34,
#     18,
#     41,
#     97,
#     86,
#     44,
#     48,
#     27,
#     8,
#     51,
#     108,
#     91,
#     96,
#     101,
#     38,
#     30,
#     62,
#     66,
#     55,
#     58,
#     104,
#     9351,
#     123,
#     139,
#     192,
#     9352,
#     191,
#   [[291]],
#   [[892]],
#   [[893]],
#   [[9360, 9363]],
#   [[9361]],
#   [[9372]],
#   [[9373]],
#   [[9378]],
#   [[9383]],
#   [[9384]],
#   [[9358]],
#   [[1793]],
#   [[3017, 3084, 3116, 3086, 3019, 2745, 3015, 3016]],
#   [[-3083, 3082, 9861]],
#   [[3201]],
#   [[2595]],
#   [[2690]],
#   [[2508]],
#   [[6873]],
#   [[6874]],
#   [[6994]],
#   [[7027]],
#   [[7028]],
#   [[4132]],
#   [[4828, 4829, 4827]],
#   [[4832, 4830, 4831]],
#   [[6241, 6240]],
#   [[9105]],
#   [[9192, 9191]],
#   [[9221]],
#   [[9298, 9271, -9249, 9272, 9299]],
#   [[9250]],
#   [[9295, 9293, 9332]],
#   [[9296, 9297]],
#   [[-7565, 7564, 9862]],
#   [[8046]],
#   [[8048]],
#   [[8049]],
#   [[8250]],
#   [[8251]],
#   [[8299]],
#   [[-8489, 8574]],
#   [[8492]],
#   [[8670]],
#   [[-9864, -8999, -8996], [-8997, 8996, 9865]],
#   [[9020]],
#   [[-9052, 9051, 9866]],
#   [[9063]],
#   [[9082]],
#   [[8757, -8754, 8758, 8759]],
#   [[8876, 8962]],
#   [[9094, 8954, 9092, 9093]],
#   [[9037]],
#   [[-9257, 9256, 9867]],
#   [[-9277, 9276, 9868]],
#   [[9314]],
#   [[9324]],
#   [[-9349]],
#   [[-9401, 9405]],
#   [[9402]],
#   [[9403]],
#   [[9404]],
#   [[9406]],
#   [[9407]],
#   [[9408]],
#   [[9409]],
#   [[9410]],
#   [[9411]],
#   [[9412]],
#   [[9413]],
#   [[9414]],
#   [[9415]],
#   [[9416]],
#   [[9417]],
#   [[9418]],
#   [[9419]],
#   [[9420]],
#   [[9421]],
#   [[9422]],
#   [[9423]],
#   [[9424]],
#   [[9425]],
#   [[9426]],
#   [[9427]],
#   [[9428]],
#   [[9429]],
#   [[9430]],
#   [[9431]],
#   [[9432]],
#   [[9433]],
#   [[9434]],
#   [[9435]],
#   [[9436]],
#   [[9437]],
#   [[9438]],
#   [[9439]],
#   [[9440]],
#   [[9441]],
#   [[9442]],
#   [[9443]],
#   [[9444]],
#   [[9445]],
#   [[9447,
#     9464,
#     9452,
#     9465,
#     9459,
#     9554,
#     9455,
#     9555,
#     9546,
#     9617,
#     9613,
#     9611,
#     9601,
#     9608,
#     9589,
#     9599,
#     9524,
#     9535,
#     9530,
#     9533,
#     9489,
#     9517,
#     9506,
#     9633,
#     9508,
#     9515,
#     -9481,
#     9516,
#     9491,
#     9492,
#     9493,
#     9531,
#     9496,
#     9532,
#     9528,
#     9534,
#     9526,
#     9600,
#     9591,
#     9595,
#     9585,
#     9596,
#     9578,
#     9597,
#     9568,
#     9558,
#     9598,
#     9479,
#     9477,
#     9463,
#     9449,
#     9446]],
#   [[9450]],
#   [[9451]],
#   [[9454]],
#   [[9460]],
#   [[9467]],
#   [[9468]],
#   [[9469]],
#   [[9470]],
#   [[9471]],
#   [[9472]],
#   [[9473]],
#   [[9474]],
#   [[9475]],
#   [[9476]],
#   [[9487, 9518, -9483, 9519, 9485, 9522]],
#   [[9488]],
#   [[9497]],
#   [[-9499, 9537]],
#   [[9500]],
#   [[9501]],
#   [[9502]],
#   [[9503]],
#   [[9504]],
#   [[9505]],
#   [[9539, 9511, 9512, 9513, 9538, 9521]],
#   [[9514]],
#   [[9536]],
#   [[9540]],
#   [[9541]],
#   [[9542]],
#   [[9547]],
#   [[9548]],
#   [[9549]],
#   [[9550]],
#   [[9569]],
#   [[9570]],
#   [[9571]],
#   [[9572]],
#   [[9573]],
#   [[9574]],
#   [[9575]],
#   [[9576]],
#   [[9579]],
#   [[9580]],
#   [[-9582, 9581, 9869]],
#   [[9583]],
#   [[9586]],
#   [[9592]],
#   [[9593]],
#   [[9594]],
#   [[9609]],
#   [[9614]],
#   [[9615]],
#   [[9616]],
#   [[9618]],
#   [[9619]],
#   [[9620]],
#   [[9621]],
#   [[9622]],
#   [[9623]],
#   [[9624]],
#   [[9625]],
#   [[9626]],
#   [[9627]],
#   [[9628]],
#   [[9629]],
#   [[9630]],
#   [[9631]],
#   [[9632]],
#   [[9774,
#     9649,
#     9753,
#     9782,
#     9643,
#     9783,
#     9825,
#     9807,
#     9686,
#     9655,
#     9716,
#     9811,
#     9711,
#     9719,
#     9751,
#     9860,
#     9831,
#     9690,
#     9729,
#     9814,
#     9724,
#     9839,
#     9845,
#     9836,
#     9855,
#     9856,
#     9847,
#     9857,
#     9827,
#     9840,
#     9777,
#     9760,
#     9815,
#     9797,
#     9678,
#     9738,
#     9823,
#     9698,
#     9785,
#     9816,
#     9657,
#     9763]],
#   [[9858]],
#   [[9832]],
#   [[9859]]]}

# %%
state_data['objects']['land'].keys()
# Out:
# dict_keys(['type', 'properties', 'arcs'])

# %%
state_data['objects']['subunits'].keys()
# Out:
# dict_keys(['type', 'geometries'])

# %%
len(state_data['objects']['subunits']['geometries'])
# Out:
# 53

# %%
state_data['objects']['subunits']['geometries'][0].keys()
# Out:
# dict_keys(['arcs', 'type', 'id', 'properties'])

# %%
# the two we are interested in:
print(state_data['objects']['subunits']['geometries'][0]['id'])
print(state_data['objects']['subunits']['geometries'][0]['properties'])
# Out:
# 53
# {'name': 'Washington'}

# %% [markdown]
# What would be available for my council dataset?

# %%
gdata['features'][0]['properties'] # these are possible keys for our tooltip
# Out:
# {'OBJECTID_1': 811,
#  'District': '5',
#  'Council_me': 'Vanna Pianfetti',
#  'ShapeSTArea': 182775829.8232422,
#  'ShapeSTLength': 209845.9339251646}

# %% [markdown]
# ### END ASIDE
#
# # Super quick: ipyleaflet

# %%
#!pip install ipyleaflet
from ipyleaflet import *
# note: you might have to close and reopen you notebook
# to see the map

m = Map(center=(52, 10), zoom=8, basemap=basemaps.Hydda.Full)

m
# Out:
# Map(center=[52, 10], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…

# %%
#!pip install ipyleaflet
from ipyleaflet import *
# note: you might have to close and reopen you notebook
# to see the map

m = Map(center=(52, 10), zoom=8, basemap=basemaps.Hydda.Full)

#(2) street maps
strata_all = basemap_to_tiles(basemaps.Strava.All)
m.add_layer(strata_all)
m
# Out:
# Map(center=[52, 10], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out_tex…
